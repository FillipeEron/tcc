# %%
from PIL import Image, ImageDraw, ImageFilter
import numpy as np
#from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import cv2
import os
import pathlib
from constantes import *
from dataset import *
from datasetBruto import *
from imagem import *
from nomeArquivo import *
from pigmentacao import *
import cv2

# %%
#imagem = cv2.imread('/home/eron/Documentos/tcc/dataset/17_11_2020-9:3:36/treino/positivo/skin-88-1.png')
#imagem = cv2.imread('/home/eron/Documentos/dataset/simulacao-real/positivo/mama_verm_pontos20_dist11.png')
#imagem = cv2.imread('/home/eron/Documentos/tcc/dataset/17_11_2020-9:3:36/treino/negativo/skin-76-2.png')
imagem = cv2.imread('/home/eron/Downloads/sophia_corte.png')
#cv2.imshow('Original', caminhoImagem)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.show()

# %%
imagem = cv2.medianBlur(imagem, 5)
plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.show()

# %%
lab = cv2.cvtColor(imagem, cv2.COLOR_BGR2LAB)

lab_planes = cv2.split(lab)

clahe = cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))

lab_planes[0] = clahe.apply(lab_planes[0])

lab = cv2.merge(lab_planes)

imagem = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)

plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))
plt.show()


cv2.imwrite('/home/eron/Downloads/sophia_corte-clahe.png', imagem)
# Out:
# True

# %%
kernel_sharpening = np.array([[-1,-1,-1], 
                              [-1, 9,-1],
                              [-1,-1,-1]])
sharpened = cv2.filter2D(imagem, -1, kernel_sharpening)
plt.imshow(cv2.cvtColor(sharpened, cv2.COLOR_BGR2RGB))
plt.show()
